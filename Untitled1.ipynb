# %% [markdown]
# ### LIBRARY ###

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("Hospinfo.csv")

# %% [markdown]
# ### Informasi yang di-dapat dan dimasukkan dalam dictionary ###

# %%
dict = {
    'attributes': 0,
    'null_attributes': 0,
    'object_attributes': 0,
    'total_records': 0,
    'number_attributes':0
}

# %%
dict['attributes'] = list(df.columns.values)
dict['null_attributes'] = list(df.loc[:, df.isnull().any()].columns)
dict['object_attributes'] = list(df.select_dtypes(['object']).columns)
dict['total_records'] = df.shape[0]
dict['number_attributes'] = list(df.select_dtypes(['float64', 'int64']).columns)

# %% [markdown]
# ### Banyak Record ###

# %%
print("Banyak Record =",dict['total_records'])
# Out:
# Banyak Record = 4812

# %% [markdown]
# ### Nama dan Jumlah Atribut ###

# %%
print("Jumlah Atribut =",len(dict['attributes']))
# Out:
# Jumlah Atribut = 29

# %%
print("Nama Atribut =",dict['attributes'])
# Out:
# Nama Atribut = ['Provider ID', 'Hospital Name', 'Address', 'City', 'State', 'ZIP Code', 'County Name', 'Phone Number', 'Hospital Type', 'Hospital Ownership', 'Emergency Services', 'Meets criteria for meaningful use of EHRs', 'Hospital overall rating', 'Hospital overall rating footnote', 'Mortality national comparison', 'Mortality national comparison footnote', 'Safety of care national comparison', 'Safety of care national comparison footnote', 'Readmission national comparison', 'Readmission national comparison footnote', 'Patient experience national comparison', 'Patient experience national comparison footnote', 'Effectiveness of care national comparison', 'Effectiveness of care national comparison footnote', 'Timeliness of care national comparison', 'Timeliness of care national comparison footnote', 'Efficient use of medical imaging national comparison', 'Efficient use of medical imaging national comparison footnote', 'Location']

# %% [markdown]
# ### Jumlah Atribut dengan Tipe Objek ###

# %%
print("Jumlah Atribut dengan Tipe Objek =",len(dict ['object_attributes']))
# Out:
# Jumlah Atribut dengan Tipe Objek = 25

# %% [markdown]
# ### Jumlah Atribute dengan tipe angka ###

# %%
print("Jumlah Atribute dengan Tipe Angka =",len(dict['number_attributes']))
# Out:
# Jumlah Atribute dengan Tipe Angka = 3

# %% [markdown]
# ### Jumlah Atribute yang memiliki null ###

# %%
print("Jumlah Atribut yang memiliki Null =",len(dict['null_attributes']))
# Out:
# Jumlah Atribut yang memiliki Null = 10

# %% [markdown]
# ### Tampilkan rata-rata, standar deviasi, nilai minimum, nilai maksimum, Q1, Q2, dan Q3 dari attribute bertipe angka ###

# %%
df.describe()
# Out:
#          Provider ID      ZIP Code  Phone Number
# count    4812.000000   4812.000000  4.812000e+03
# mean   268294.422901  53990.132377  5.848244e+09
# std    157109.340215  26915.916870  2.332196e+09
# min     10001.000000    603.000000  9.369338e+08
# 25%    140185.750000  33015.250000  4.014563e+09
# 50%    260043.500000  55410.500000  6.053360e+09
# 75%    390222.250000  76035.500000  7.877574e+09
# max    670118.000000  99929.000000  9.898943e+09

# %% [markdown]
# ### Tampilkan nilai korelasi attribute bertipe angka ###

# %%
df.corr()
# Out:
#                     Provider ID  ZIP Code  Phone Number  Emergency Services
# Provider ID            1.000000 -0.110463      0.022860            0.044191
# ZIP Code              -0.110463  1.000000      0.021930           -0.041373
# Phone Number           0.022860  0.021930      1.000000            0.015448
# Emergency Services     0.044191 -0.041373      0.015448            1.000000

# %% [markdown]
# ### Mengubah Atribut Menjadi Desimal ###

# %% [markdown]
# ### "Sebelum Provider ID diubah" ###

# %%
df.dtypes
# Out:
# Provider ID                                                       int64
# Hospital Name                                                    object
# Address                                                          object
# City                                                             object
# State                                                            object
# ZIP Code                                                          int64
# County Name                                                      object
# Phone Number                                                      int64
# Hospital Type                                                    object
# Hospital Ownership                                               object
# Emergency Services                                                 bool
# Meets criteria for meaningful use of EHRs                        object
# Hospital overall rating                                          object
# ...

# %%
df['Provider ID'] = df['Provider ID'].astype("float64")

# %% [markdown]
# ### sesudah Provider ID diubah ###

# %%
df.head(10)
# Out:
#    Provider ID                       Hospital Name  \
# 0      10005.0       MARSHALL MEDICAL CENTER SOUTH
# 1      10012.0      DEKALB REGIONAL MEDICAL CENTER
# 2      10032.0                    WEDOWEE HOSPITAL
# 3      10095.0                HALE COUNTY HOSPITAL
# 4      10131.0            CRESTWOOD MEDICAL CENTER
# 5      11304.0            CHOCTAW GENERAL HOSPITAL
# 6      20018.0  YUKON KUSKOKWIM DELTA REG HOSPITAL
# 7      21308.0      NORTON SOUND REGIONAL HOSPITAL
# 8      21309.0                  KANAKANAK HOSPITAL
# 9      21310.0              MANIILAQ HEALTH CENTER
#
#                                    Address        City State  ZIP Code  \
# 0               2505 U S HIGHWAY 431 NORTH        BOAZ    AL     35957
# 1                     200 MED CENTER DRIVE  FORT PAYNE    AL     35968
# 2                    209 NORTH MAIN STREET     WEDOWEE    AL     36278
# 3                         508 GREEN STREET  GREENSBORO    AL     36744
# ...

# %%
df.dtypes
# Out:
# Provider ID                                                      float64
# Hospital Name                                                     object
# Address                                                           object
# City                                                              object
# State                                                             object
# ZIP Code                                                           int64
# County Name                                                       object
# Phone Number                                                       int64
# Hospital Type                                                     object
# Hospital Ownership                                                object
# Emergency Services                                                  bool
# Meets criteria for meaningful use of EHRs                         object
# Hospital overall rating                                           object
# ...

# %% [markdown]
# ### Tampilkan 10 record pertama dari attribute bertipe angka ###

# %%
dh = df.select_dtypes(include=np.number)
dh.head(10)
# Out:
#    Provider ID  ZIP Code  Phone Number
# 0      10005.0     35957    2565938310
# 1      10012.0     35968    2568453150
# 2      10032.0     36278    2563572111
# 3      10095.0     36744    3346243024
# 4      10131.0     35801    2568823100
# 5      11304.0     36904    2054599100
# 6      20018.0     99559    9075436300
# 7      21308.0     99762    9074433311
# 8      21309.0     99576    9078425201
# 9      21310.0     99752    9074423321

# %% [markdown]
# ### Simpan dataset dengan attribute bertipe angka ke dalam file CSV ###

# %%
variabel= df.select_dtypes(include=np.number)
variabel.to_csv("info.csv")
